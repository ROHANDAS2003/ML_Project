# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Normalization
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd

# Set seeds for reproducibility
tf.random.set_seed(10)
np.random.seed(10)

# %%
# Load data
train_df = pd.read_csv('playground-series-s5e5/train.csv')

# Encode 'Sex' column: male=1, female=0
train_df['Sex'] = train_df['Sex'].map({'male': 1, 'female': 0})

# Features and target
X = train_df.drop(columns=['id', 'Calories']).values
y = train_df['Calories'].values

# Split into train and validation
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.1, random_state=42
)

# Create normalization layer and adapt on training features
normalizer = Normalization()
normalizer.adapt(X_train)

# %%
input_layer = Input(shape=(X_train.shape[1],))
x = normalizer(input_layer)

# Branch 1
x1 = Dense(128, activation='relu')(x)
x1 = Dense(64, activation='sigmoid')(x1)
x1 = Dense(32, activation='tanh')(x1)

# Branch 2
x2 = Dense(16, activation='sigmoid')(x)
x2 = Dense(8, activation='tanh')(x2)

combined = concatenate([x1, x2])
output = Dense(1, activation='relu')(combined)

model = Model(inputs=input_layer, outputs=output)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 7)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 7)         │         15 │ input_layer[0][0] │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │      1,024 │ normalization[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 16)        │        128 │ normalization[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 32)        │      2,080 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 8)         │        136 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 40)        │          0 │ dense_2[0][0],    │
# │ (Concatenate)       │                   │            │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │         41 │ concatenate[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,680 (45.63 KB)
#  Trainable params: 11,665 (45.57 KB)
#  Non-trainable params: 15 (64.00 B)

# %%
def rmsle(y_true, y_pred):
    y_true = tf.clip_by_value(y_true, 0, np.inf)
    y_pred = tf.clip_by_value(y_pred, 0, np.inf)
    first_log = tf.math.log1p(y_pred)
    second_log = tf.math.log1p(y_true)
    return tf.sqrt(tf.reduce_mean(tf.square(first_log - second_log)))

model.compile(optimizer=Adam(learning_rate=0.0001), loss=rmsle, metrics=[rmsle])

# %%
class RMSLELogger(Callback):
    def __init__(self, validation_data):
        super().__init__()
        self.validation_data = validation_data

    def on_epoch_end(self, epoch, logs=None):
        X_val, y_val = self.validation_data
        val_preds = self.model.predict(X_val, verbose=0)
        val_preds = np.clip(val_preds, 0, None)
        y_val_clip = np.clip(y_val, 0, None)
        val_rmsle = np.sqrt(np.mean(np.square(np.log1p(val_preds) - np.log1p(y_val_clip))))
        print(f"Epoch {epoch + 1}: val_RMSLE = {val_rmsle:.5f}")

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1, min_lr=1e-6),
    RMSLELogger(validation_data=(X_val, y_val))
]

history = model.fit(
    X_train[:50000], y_train[:50000],
    validation_data=(X_val, y_val),
    epochs=200,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/200
# 737/782 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - loss: 3.1299 - rmsle: 3.1306

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['rmsle'], label='Train RMSLE')
plt.plot(history.history['val_rmsle'], label='Validation RMSLE')
plt.xlabel('Epoch')
plt.ylabel('RMSLE')
plt.title('Train vs Validation RMSLE')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Map 'Sex' to numerical values
sex_map = {'male': 0, 'female': 1}
train_df['Sex'] = train_df['Sex'].map(sex_map)
test_df['Sex'] = test_df['Sex'].map(sex_map)

# Calculate height in meters
train_df['Height_m'] = train_df['Height'] / 100
test_df['Height_m'] = test_df['Height'] / 100

# Calculate BMI
train_df['BMI'] = train_df['Weight'] / (train_df['Height_m'] ** 2)
test_df['BMI'] = test_df['Weight'] / (test_df['Height_m'] ** 2)

# Add Calories per Minute (for analysis only, not used in features)
train_df['Calories_per_min'] = train_df['Calories'] / train_df['Duration']

# Define features
features = ['Sex', 'Age', 'Height', 'Weight', 'Duration', 'Heart_Rate', 'Body_Temp', 'BMI']
X = train_df[features].values
y = np.log1p(train_df['Calories'].values)  # log1p for RMSLE handling
X_test = test_df[features].values

# %%
def rmsle(y_true, y_pred):
    y_true = tf.clip_by_value(y_true, 0, np.inf)
    y_pred = tf.clip_by_value(y_pred, 0, np.inf)
    first_log = tf.math.log1p(y_pred)
    second_log = tf.math.log1p(y_true)
    return tf.sqrt(tf.reduce_mean(tf.square(first_log - second_log)))

# %%
X_train_sub, X_val, y_train_sub, y_val = train_test_split(
    X_train, y_train, test_size=0.1, random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 X_train_sub, X_val, y_train_sub, y_val = train_test_split(
# ----> 2     X_train, y_train, test_size=0.1, random_state=42
#       3 )
#
# NameError: name 'X_train' is not defined

# %%
tf.random.set_seed(10)
np.random.seed(10)

# --- Input Layer ---
input_layer = Input(shape=(X_train.shape[1],))
x = normalizer(input_layer)

# --- Branch: model ---
x1 = Dense(128, activation='relu')(x)
x1 = Dense(64, activation='sigmoid')(x1)
x1 = Dense(32, activation='tanh')(x1)

# --- Branch: model1 ---
x2 = Dense(16, activation='sigmoid')(x)
x2 = Dense(8, activation='tanh')(x2)

# --- Concatenate ---
combined = concatenate([x1, x2])

output = Dense(1, activation='relu')(combined)

# --- Build Model ---
ensemble_model = Model(inputs=input_layer, outputs=output)
ensemble_model.compile(optimizer=Adam(learning_rate=0.0001), loss=rmsle, metrics=[rmsle])

# --- Callbacks ---
class RMSLELogger(Callback):
    def __init__(self, validation_data):
        super().__init__()
        self.validation_data = validation_data  # (X_val, y_val)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        X_val, y_val = self.validation_data
        val_preds = self.model.predict(X_val, verbose=0)
        val_preds = np.clip(val_preds, 0, None)
        y_val = np.clip(y_val, 0, None)
        rmsle_val = np.sqrt(np.mean(np.square(np.log1p(val_preds) - np.log1p(y_val))))
        print(f"Epoch {epoch+1}: val_RMSLE = {rmsle_val:.5f}")

# %%
ensemble_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 8)         │         17 │ input_layer_2[0]… │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 128)       │      1,152 │ normalization[2]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 64)        │      8,256 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 16)        │        144 │ normalization[2]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 32)        │      2,080 │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 8)         │        136 │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 40)        │          0 │ dense_14[0][0],   │
# │ (Concatenate)       │                   │            │ dense_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 1)         │         41 │ concatenate_2[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,826 (46.20 KB)
#  Trainable params: 11,809 (46.13 KB)
#  Non-trainable params: 17 (72.00 B)

# %%
# Split into training and validation sets
X_train_sub, X_val, y_train_sub, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)
rmsle_logger = RMSLELogger(validation_data=(X_val, y_val))

# %%
# --- Train Model ---
history = ensemble_model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=200,
    batch_size=256,
    callbacks=callbacks,
    verbose=1
)

# --- Plot Loss ---
plt.figure(figsize=(8, 5))
plt.plot(history.history['rmsle'], label='Train RMSLE')
plt.plot(history.history['val_rmsle'], label='Validation RMSLE')
plt.xlabel('Epoch')
plt.ylabel('RMSLE')
plt.title('Train vs Validation RMSLE')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/200
# 2327/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - loss: 1.6305 - rmsle: 1.6305
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 # --- Train Model ---
# ----> 2 history = ensemble_model.fit(
#       3     X_train, y_train,
#       4     validation_split=0.1,
#       5     epochs=200,
#       6     batch_size=256,
#       7     callbacks=callbacks,
#       8     verbose=1
#       9 )
#      11 # --- Plot Loss ---
#      12 plt.figure(figsize=(8, 5))
#
# File ~/Documents/GitHub/ML_Project/tfenv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# Cell In[5], line 30, in RMSLELogger.on_epoch_end(self, epoch, logs)
#      28 def on_epoch_end(self, epoch, logs=None):
#      29     logs = logs or {}
# ---> 30     val_preds = self.model.predict(self.validation_data[0], verbose=0)
#      31     val_true = self.validation_data[1]
#      33     val_preds = np.clip(val_preds, 0, None)
#
# AttributeError: 'RMSLELogger' object has no attribute 'validation_data'

# %%
# --- RMSLE Evaluation ---
split_idx = int(0.9 * len(X_train))
train_preds_log = ensemble_model.predict(X_train[:split_idx], verbose=0)
train_true = y_train[:split_idx]

train_preds = np.expm1(train_preds_log)
train_true_exp = np.expm1(train_true)

rmsle_train = np.sqrt(np.mean((np.log1p(train_preds.flatten()) - np.log1p(train_true_exp))**2))
print(f"\nTrain RMSLE: {rmsle_train:.5f}")

val_preds_log = ensemble_model.predict(X_train[split_idx:], verbose=0)
val_true = y_train[split_idx:]

val_preds = np.expm1(val_preds_log)
val_true_exp = np.expm1(val_true)

rmsle_val = np.sqrt(np.mean((np.log1p(val_preds.flatten()) - np.log1p(val_true_exp))**2))
print(f"Validation RMSLE: {rmsle_val:.5f}")
# Out:
# Train RMSLE: 5.03627
# Validation RMSLE: 5.03400

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_log_error
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Standard scaling (XGBoost can work without scaling, but consistent normalization is good for comparison)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

xgb.XGBRegressor(
    learning_rate=0.02,
    n_estimators=800,
    max_depth=5,
    min_child_weight=5,
    gamma=1.0,
    subsample=0.7,
    colsample_bytree=0.6,
    reg_alpha=1.0,
    reg_lambda=2.0,
    random_state=42
)

# Train
xgb_model.fit(
    X_train_scaled, y_train,
    eval_set=[(X_val_scaled, y_val)],
    verbose=True
)

# Predict (log scale)
train_preds_log = xgb_model.predict(X_train_scaled)
val_preds_log = xgb_model.predict(X_val_scaled)

# Convert back from log1p
train_preds = np.expm1(train_preds_log)
train_true = np.expm1(y_train)

val_preds = np.expm1(val_preds_log)
val_true = np.expm1(y_val)

# Calculate RMSLE
rmsle_train = np.sqrt(mean_squared_log_error(train_true, train_preds))
rmsle_val = np.sqrt(mean_squared_log_error(val_true, val_preds))

print(f"\nXGBoost Train RMSLE: {rmsle_train:.5f}")
print(f"XGBoost Validation RMSLE: {rmsle_val:.5f}")
# Out:
# [0]	validation_0-rmse:0.91860
# [1]	validation_0-rmse:0.87392
# [2]	validation_0-rmse:0.83128
# [3]	validation_0-rmse:0.79094
# [4]	validation_0-rmse:0.75309
# [5]	validation_0-rmse:0.71654
# [6]	validation_0-rmse:0.68207
# [7]	validation_0-rmse:0.64909
# [8]	validation_0-rmse:0.61878
# [9]	validation_0-rmse:0.58900
# [10]	validation_0-rmse:0.56095
# [11]	validation_0-rmse:0.53410
# [12]	validation_0-rmse:0.50884
# [13]	validation_0-rmse:0.48477
# [14]	validation_0-rmse:0.46198
# [15]	validation_0-rmse:0.44038
# [16]	validation_0-rmse:0.42204
# [17]	validation_0-rmse:0.40230
# [18]	validation_0-rmse:0.38358
# [19]	validation_0-rmse:0.36572
# [20]	validation_0-rmse:0.34878
# [21]	validation_0-rmse:0.33270
# [22]	validation_0-rmse:0.31789
# [23]	validation_0-rmse:0.30362
# [24]	validation_0-rmse:0.29012
# [25]	validation_0-rmse:0.27758
# [26]	validation_0-rmse:0.26532
# [27]	validation_0-rmse:0.25363
# [28]	validation_0-rmse:0.24283
# [29]	validation_0-rmse:0.23252
# [30]	validation_0-rmse:0.22260
# [31]	validation_0-rmse:0.21322
# [32]	validation_0-rmse:0.20440
# [33]	validation_0-rmse:0.19590
# [34]	validation_0-rmse:0.18792
# [35]	validation_0-rmse:0.18032
# [36]	validation_0-rmse:0.17339
# [37]	validation_0-rmse:0.16670
# [38]	validation_0-rmse:0.16039
# [39]	validation_0-rmse:0.15428
# [40]	validation_0-rmse:0.14877
# [41]	validation_0-rmse:0.14353
# [42]	validation_0-rmse:0.13854
# [43]	validation_0-rmse:0.13388
# [44]	validation_0-rmse:0.12960
# [45]	validation_0-rmse:0.12561
# [46]	validation_0-rmse:0.12163
# [47]	validation_0-rmse:0.11785
# [48]	validation_0-rmse:0.11430
# [49]	validation_0-rmse:0.11094
# [50]	validation_0-rmse:0.10798
# [51]	validation_0-rmse:0.10522
# [52]	validation_0-rmse:0.10248
# [53]	validation_0-rmse:0.09991
# [54]	validation_0-rmse:0.09772
# [55]	validation_0-rmse:0.09562
# [56]	validation_0-rmse:0.09349
# [57]	validation_0-rmse:0.09172
# [58]	validation_0-rmse:0.08982
# [59]	validation_0-rmse:0.08802
# [60]	validation_0-rmse:0.08634
# [61]	validation_0-rmse:0.08479
# [62]	validation_0-rmse:0.08353
# [63]	validation_0-rmse:0.08237
# [64]	validation_0-rmse:0.08109
# [65]	validation_0-rmse:0.07988
# [66]	validation_0-rmse:0.07892
# [67]	validation_0-rmse:0.07786
# [68]	validation_0-rmse:0.07689
# [69]	validation_0-rmse:0.07613
# [70]	validation_0-rmse:0.07528
# [71]	validation_0-rmse:0.07455
# [72]	validation_0-rmse:0.07393
# [73]	validation_0-rmse:0.07325
# [74]	validation_0-rmse:0.07263
# [75]	validation_0-rmse:0.07200
# [76]	validation_0-rmse:0.07150
# [77]	validation_0-rmse:0.07097
# [78]	validation_0-rmse:0.07044
# [79]	validation_0-rmse:0.07001
# [80]	validation_0-rmse:0.06961
# [81]	validation_0-rmse:0.06926
# [82]	validation_0-rmse:0.06888
# [83]	validation_0-rmse:0.06854
# [84]	validation_0-rmse:0.06820
# [85]	validation_0-rmse:0.06792
# [86]	validation_0-rmse:0.06767
# [87]	validation_0-rmse:0.06743
# [88]	validation_0-rmse:0.06721
# [89]	validation_0-rmse:0.06697
# [90]	validation_0-rmse:0.06673
# [91]	validation_0-rmse:0.06656
# [92]	validation_0-rmse:0.06639
# [93]	validation_0-rmse:0.06620
# [94]	validation_0-rmse:0.06606
# [95]	validation_0-rmse:0.06586
# [96]	validation_0-rmse:0.06571
# [97]	validation_0-rmse:0.06557
# [98]	validation_0-rmse:0.06541
# [99]	validation_0-rmse:0.06527
# [100]	validation_0-rmse:0.06516
# [101]	validation_0-rmse:0.06503
# [102]	validation_0-rmse:0.06491
# [103]	validation_0-rmse:0.06482
# [104]	validation_0-rmse:0.06473
# [105]	validation_0-rmse:0.06463
# [106]	validation_0-rmse:0.06453
# [107]	validation_0-rmse:0.06445
# [108]	validation_0-rmse:0.06438
# [109]	validation_0-rmse:0.06429
# [110]	validation_0-rmse:0.06421
# [111]	validation_0-rmse:0.06415
# [112]	validation_0-rmse:0.06410
# [113]	validation_0-rmse:0.06402
# [114]	validation_0-rmse:0.06397
# [115]	validation_0-rmse:0.06391
# [116]	validation_0-rmse:0.06383
# [117]	validation_0-rmse:0.06377
# [118]	validation_0-rmse:0.06374
# [119]	validation_0-rmse:0.06370
# [120]	validation_0-rmse:0.06364
# [121]	validation_0-rmse:0.06360
# [122]	validation_0-rmse:0.06356
# [123]	validation_0-rmse:0.06350
# [124]	validation_0-rmse:0.06345
# [125]	validation_0-rmse:0.06340
# [126]	validation_0-rmse:0.06336
# [127]	validation_0-rmse:0.06330
# [128]	validation_0-rmse:0.06327
# [129]	validation_0-rmse:0.06323
# [130]	validation_0-rmse:0.06319
# [131]	validation_0-rmse:0.06316
# [132]	validation_0-rmse:0.06314
# [133]	validation_0-rmse:0.06311
# [134]	validation_0-rmse:0.06307
# [135]	validation_0-rmse:0.06304
# [136]	validation_0-rmse:0.06301
# [137]	validation_0-rmse:0.06299
# [138]	validation_0-rmse:0.06296
# [139]	validation_0-rmse:0.06295
# [140]	validation_0-rmse:0.06293
# [141]	validation_0-rmse:0.06290
# [142]	validation_0-rmse:0.06289
# [143]	validation_0-rmse:0.06287
# [144]	validation_0-rmse:0.06286
# [145]	validation_0-rmse:0.06283
# [146]	validation_0-rmse:0.06279
# [147]	validation_0-rmse:0.06276
# [148]	validation_0-rmse:0.06275
# [149]	validation_0-rmse:0.06273
# [150]	validation_0-rmse:0.06271
# [151]	validation_0-rmse:0.06269
# [152]	validation_0-rmse:0.06267
# [153]	validation_0-rmse:0.06265
# [154]	validation_0-rmse:0.06263
# [155]	validation_0-rmse:0.06262
# [156]	validation_0-rmse:0.06260
# [157]	validation_0-rmse:0.06258
# [158]	validation_0-rmse:0.06257
# [159]	validation_0-rmse:0.06256
# [160]	validation_0-rmse:0.06254
# [161]	validation_0-rmse:0.06253
# [162]	validation_0-rmse:0.06250
# [163]	validation_0-rmse:0.06249
# [164]	validation_0-rmse:0.06248
# [165]	validation_0-rmse:0.06247
# [166]	validation_0-rmse:0.06246
# [167]	validation_0-rmse:0.06245
# [168]	validation_0-rmse:0.06243
# [169]	validation_0-rmse:0.06242
# [170]	validation_0-rmse:0.06241
# [171]	validation_0-rmse:0.06240
# [172]	validation_0-rmse:0.06238
# [173]	validation_0-rmse:0.06236
# [174]	validation_0-rmse:0.06234
# [175]	validation_0-rmse:0.06234
# [176]	validation_0-rmse:0.06234
# [177]	validation_0-rmse:0.06233
# [178]	validation_0-rmse:0.06233
# [179]	validation_0-rmse:0.06232
# [180]	validation_0-rmse:0.06231
# [181]	validation_0-rmse:0.06229
# [182]	validation_0-rmse:0.06227
# [183]	validation_0-rmse:0.06226
# [184]	validation_0-rmse:0.06226
# [185]	validation_0-rmse:0.06224
# [186]	validation_0-rmse:0.06223
# [187]	validation_0-rmse:0.06221
# [188]	validation_0-rmse:0.06222
# [189]	validation_0-rmse:0.06220
# [190]	validation_0-rmse:0.06218
# [191]	validation_0-rmse:0.06216
# [192]	validation_0-rmse:0.06215
# [193]	validation_0-rmse:0.06213
# [194]	validation_0-rmse:0.06211
# [195]	validation_0-rmse:0.06209
# [196]	validation_0-rmse:0.06209
# [197]	validation_0-rmse:0.06206
# [198]	validation_0-rmse:0.06205
# [199]	validation_0-rmse:0.06204
# [200]	validation_0-rmse:0.06203
# [201]	validation_0-rmse:0.06202
# [202]	validation_0-rmse:0.06201
# [203]	validation_0-rmse:0.06200
# [204]	validation_0-rmse:0.06198
# [205]	validation_0-rmse:0.06197
# [206]	validation_0-rmse:0.06197
# [207]	validation_0-rmse:0.06196
# [208]	validation_0-rmse:0.06195
# [209]	validation_0-rmse:0.06194
# [210]	validation_0-rmse:0.06192
# [211]	validation_0-rmse:0.06191
# [212]	validation_0-rmse:0.06192
# [213]	validation_0-rmse:0.06192
# [214]	validation_0-rmse:0.06191
# [215]	validation_0-rmse:0.06189
# [216]	validation_0-rmse:0.06188
# [217]	validation_0-rmse:0.06188
# [218]	validation_0-rmse:0.06187
# [219]	validation_0-rmse:0.06187
# [220]	validation_0-rmse:0.06186
# [221]	validation_0-rmse:0.06185
# [222]	validation_0-rmse:0.06184
# [223]	validation_0-rmse:0.06184
# [224]	validation_0-rmse:0.06184
# [225]	validation_0-rmse:0.06184
# [226]	validation_0-rmse:0.06183
# [227]	validation_0-rmse:0.06183
# [228]	validation_0-rmse:0.06182
# [229]	validation_0-rmse:0.06181
# [230]	validation_0-rmse:0.06181
# [231]	validation_0-rmse:0.06180
# [232]	validation_0-rmse:0.06180
# [233]	validation_0-rmse:0.06179
# [234]	validation_0-rmse:0.06178
# [235]	validation_0-rmse:0.06177
# [236]	validation_0-rmse:0.06176
# [237]	validation_0-rmse:0.06176
# [238]	validation_0-rmse:0.06175
# [239]	validation_0-rmse:0.06174
# [240]	validation_0-rmse:0.06173
# [241]	validation_0-rmse:0.06173
# [242]	validation_0-rmse:0.06172
# [243]	validation_0-rmse:0.06171
# [244]	validation_0-rmse:0.06171
# [245]	validation_0-rmse:0.06170
# [246]	validation_0-rmse:0.06169
# [247]	validation_0-rmse:0.06169
# [248]	validation_0-rmse:0.06168
# [249]	validation_0-rmse:0.06168
# [250]	validation_0-rmse:0.06167
# [251]	validation_0-rmse:0.06168
# [252]	validation_0-rmse:0.06167
# [253]	validation_0-rmse:0.06167
# [254]	validation_0-rmse:0.06166
# [255]	validation_0-rmse:0.06166
# [256]	validation_0-rmse:0.06166
# [257]	validation_0-rmse:0.06165
# [258]	validation_0-rmse:0.06165
# [259]	validation_0-rmse:0.06164
# [260]	validation_0-rmse:0.06164
# [261]	validation_0-rmse:0.06164
# [262]	validation_0-rmse:0.06163
# [263]	validation_0-rmse:0.06163
# [264]	validation_0-rmse:0.06162
# [265]	validation_0-rmse:0.06162
# [266]	validation_0-rmse:0.06163
# [267]	validation_0-rmse:0.06162
# [268]	validation_0-rmse:0.06163
# [269]	validation_0-rmse:0.06162
# [270]	validation_0-rmse:0.06162
# [271]	validation_0-rmse:0.06161
# [272]	validation_0-rmse:0.06161
# [273]	validation_0-rmse:0.06162
# [274]	validation_0-rmse:0.06161
# [275]	validation_0-rmse:0.06161
# [276]	validation_0-rmse:0.06161
# [277]	validation_0-rmse:0.06161
# [278]	validation_0-rmse:0.06161
# [279]	validation_0-rmse:0.06161
# [280]	validation_0-rmse:0.06161
# [281]	validation_0-rmse:0.06160
# [282]	validation_0-rmse:0.06159
# [283]	validation_0-rmse:0.06160
# [284]	validation_0-rmse:0.06159
# [285]	validation_0-rmse:0.06159
# [286]	validation_0-rmse:0.06159
# [287]	validation_0-rmse:0.06159
# [288]	validation_0-rmse:0.06158
# [289]	validation_0-rmse:0.06158
# [290]	validation_0-rmse:0.06158
# [291]	validation_0-rmse:0.06158
# [292]	validation_0-rmse:0.06158
# [293]	validation_0-rmse:0.06156
# [294]	validation_0-rmse:0.06156
# [295]	validation_0-rmse:0.06156
# [296]	validation_0-rmse:0.06155
# [297]	validation_0-rmse:0.06155
# [298]	validation_0-rmse:0.06155
# [299]	validation_0-rmse:0.06155
#
# XGBoost Train RMSLE: 0.05814
# XGBoost Validation RMSLE: 0.06155

# %%
# --- Predict with ensemble model ---
split_idx = int(0.9 * len(X_train))

# Ensemble predictions (log scale)
ensemble_train_preds_log = ensemble_model.predict(X_train[:split_idx], verbose=0).flatten()
ensemble_val_preds_log = ensemble_model.predict(X_train[split_idx:], verbose=0).flatten()

# XGBoost predictions (log scale)
xgb_train_preds_log = xgb_model.predict(X_train_scaled[:split_idx])
xgb_val_preds_log = xgb_model.predict(X_train_scaled[split_idx:])

# --- Average predictions in log scale ---
avg_train_preds_log = (ensemble_train_preds_log + xgb_train_preds_log) / 2
avg_val_preds_log = (ensemble_val_preds_log + xgb_val_preds_log) / 2

# --- Convert back from log1p ---
avg_train_preds = np.expm1(avg_train_preds_log)
avg_val_preds = np.expm1(avg_val_preds_log)

# Ground truths (expm1)
train_true_exp = np.expm1(y_train[:split_idx])
val_true_exp = np.expm1(y_train[split_idx:])

# --- Calculate RMSLE for averaged predictions ---
rmsle_train_avg = np.sqrt(np.mean((np.log1p(avg_train_preds) - np.log1p(train_true_exp)) ** 2))
rmsle_val_avg = np.sqrt(np.mean((np.log1p(avg_val_preds) - np.log1p(val_true_exp)) ** 2))

print(f"\nAveraged Prediction Train RMSLE: {rmsle_train_avg:.5f}")
print(f"Averaged Prediction Validation RMSLE: {rmsle_val_avg:.5f}")
# Out:
# Averaged Prediction Train RMSLE: 0.05844
# Averaged Prediction Validation RMSLE: 0.05752
